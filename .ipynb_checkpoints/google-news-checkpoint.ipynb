# %%
import asyncio
import importlib
import os
import warnings

from google.adk.agents import Agent
#from google.adk.models.lite_llm import LiteLlm  # For multi-model support
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools.tool_context import ToolContext
from google.genai import types  # For creating message Content/Parts
from IPython.display import HTML, Markdown, display

# Ignore all warnings
warnings.filterwarnings("ignore")

import logging

logging.basicConfig(level=logging.ERROR)

# Set `PATH` to include the directory containing ADK command
# PATH = %env PATH
# %env PATH=/home/jupyter/.local/bin:{PATH}

# %%
# !pip install google-adk
# Out:
# Requirement already satisfied: google-adk in /opt/conda/lib/python3.10/site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /opt/conda/lib/python3.10/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from google-adk) (8.1.8)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (0.118.2)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.184.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /opt/conda/lib/python3.10/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (3.4.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /opt/conda/lib/python3.10/site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (2.0.43)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /opt/conda/lib/python3.10/site-packages (from google-adk) (0.48.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /opt/conda/lib/python3.10/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /opt/conda/lib/python3.10/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (0.37.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.10/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /opt/conda/lib/python3.10/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.10/site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.21.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.41.1)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.24.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (24.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.21.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.49.0rc1)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.1)
# Requirement already satisfied: google-cloud-trace<2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.2)
# Requirement already satisfied: sqlparse>=0.4.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/jupyter/.local/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/conda/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/jupyter/.local/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.11.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.10/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.27.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.10/site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (1.26.20)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /home/jupyter/.local/lib/python3.10/site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.23.5)
# Requirement already satisfied: greenlet>=1 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.27.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.22)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.10/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: tomli in /opt/conda/lib/python3.10/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (2.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)

# %%
LOCATION = "us-central1"
os.environ["GOOGLE_CLOUD_LOCATION"] = LOCATION
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "TRUE"  # Use Vertex AI API
os.environ["GOOGLE_CLOUD_PROJECT"] = "nghiale-demo"  # Use Vertex AI API

# %%
# %%bash
# # -p オプションを付けて adk_agents/ ディレクトリを作成します。
# # -p は、ディレクトリが既に存在してもエラーを出さず、親ディレクトリも同時に作成します。
# mkdir -p adk_agents

# %%
# %%bash
# echo > adk_agents/.env "GOOGLE_CLOUD_LOCATION=$GOOGLE_CLOUD_LOCATION
# GOOGLE_CLOUD_PROJECT=$GOOGLE_CLOUD_PROJECT
#
# GOOGLE_GENAI_USE_VERTEXAI=$GOOGLE_GENAI_USE_VERTEXAI
# "

# %%
MODEL = "gemini-2.0-flash"

# %%
# %%bash
# # 必要なディレクトリ構造をすべて作成します。
# # -p オプションは、パスの中間にあるディレクトリもすべて作成し、
# # すでに存在してもエラーを出さないため安全です。
# mkdir -p ./adk_agents/agent1_news_collector

# %%
# %%writefile ./adk_agents/agent1_news_collector/tools.py

import pandas as pd
from GoogleNews import GoogleNews # GoogleNewsなどの必要なライブラリもインポート
import json
from google import genai
from google.genai.errors import APIError

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)


def fetch_stock_news_from_google_news(query:str):
    """Retrieves recent news articles related to a specific financial or market query from Google News.

    Args:
        query (str): The keyword or phrase for the search (e.g., "Toyota stock forecast", "Nikkei 225 news").
        
    Returns:
        dict: A Data dictionary containing the collected news data (e.g., Title, Summary, Source, URL).
    """
    print(f"✅ 検索キーワード: '{query}' でGoogle Newsを検索中...")

    # GoogleNewsオブジェクトを初期化
    googlenews = GoogleNews(lang='en', region='US') # 日本語、日本リージョンで設定
    # googlenews = GoogleNews(lang='ja', region='ja') # 日本語、日本リージョンで設定
    # 検索クエリを設定し、指定ページ数まで結果を取得
    googlenews.search(query)
    
    # 結果を取得
    results = googlenews.results()
    
    news_data = {} # 辞書型として初期化
    article_index = 1 # 記事のキーとして使用するカウンター

    for item in results:
        # 必要な情報を抽出し、一時的なディクショナリ（記事データ）を作成
        article_dict = {
            'title': item.get('title'),
            'source': item.get('publisher'),
            'date': item.get('date'),
            'url': item.get('link'),
            'summary': item.get('desc')
        }
    
        # 💡 修正点: .append() の代わりに、連番をキーとしてディクショナリに保存
        news_data[f'article_{article_index}'] = article_dict
        
        # 次のキーのためにカウンターを増やす
        article_index += 1
    
    if not news_data:
        print("❌ 該当するニュース記事が見つかりませんでした。")
        return {
            "status": "failed",
            "count": 0,
            "message": "No news articles found for the query.",
            "articles": []
        }

    print(f"✅ 合計 {len(news_data)} 件の記事が見つかりました。")
    print("#######################",news_data)
    # ファイルに書き込む
    with open("./data.json", 'w', encoding='utf-8') as f:
        # indent=4 で整形して書き込むと、ファイルが読みやすくなります
        json.dump(news_data, f)

    return {"status": "OK"}


def predict_index(target_index: str, query: str) -> dict:
    """The minimum function required to analyze news articles and have Gemini generate a prediction and its rationale."""
    # ----------------------------------------------------
    # 💡 注意: clientは通常モジュールレベルで一度だけ初期化します
    # ファイルを読み込む
    with open("./data.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print("######data",data)
    try:
        client = genai.Client()
        print("Gemini Clientの初期化しました")
    except Exception as e:
        # 環境変数または認証情報に問題がある可能性があります
        print(f"Gemini Clientの初期化に失敗しました: {e}")
        client = None
    # ----------------------------------------------------
    # 1. 最小限の初期チェック
    if client is None:
        return {"status": "error", "message": "Client not initialized."}

    if not query:
        return {"status": "data_insufficient", "message": "No news data provided."}

    
    # 3. 最小限のプロンプトと必須JSON形式
    prompt = f"""
    Based *only* on the provided news articles in the {data}, analyze the sentiment and predict the closing direction for the **{target_index}** index. 
    Output the result strictly in the required JSON format.

    News Articles:
    ---
    {query}
    ---

    Required JSON Format:
    {{
      "predicted_close": <float or current index value>,
      "market_sentiment": "<Bullish|Bearish|Neutral>",
      "analysis_basis": "<Concise summary of the market drivers, max 50 words>"
    }}
    """
    
    # 4. API呼び出しと最小限のエラー処理
    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=prompt,
            config={"response_mime_type": "application/json"}
        )
        
        # JSON応答をパース
        llm_analysis = json.loads(response.text)
        
        # 💡 デバッグ用: 応答が成功した場合、Geminiの解析結果をそのまま返して構造を確認
        return {
            "prediction_status": "success",
            "target_index": target_index,
            "llm_output": llm_analysis # 解析結果全体を返して確認
        }

    except Exception as e:
        # ネットワーク、認証、JSONパースなど、全てのエラーをキャッチ
        return {
            "prediction_status": "runtime_error",
            "message": f"An unexpected error occurred during API call or JSON parsing: {type(e).__name__}: {str(e)}",
            "error_type": type(e).__name__
        }
# Out:
# Overwriting ./adk_agents/agent1_news_collector/tools.py

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %%writefile ./adk_agents/agent1_news_collector/agent.py
from google.adk.agents import Agent
from google.adk.tools import AgentTool

from .tools import fetch_stock_news_from_google_news, predict_index

google_search_agent = Agent(
    name="google_search_agent",
    model="gemini-2.0-flash",
    instruction="Retrieves recent news articles from Google News.",
    tools=[fetch_stock_news_from_google_news]
)

predict_agent = Agent(
    name="predict_index_price_agent",
    model="gemini-2.0-flash",
    instruction="Predict the closing price of a stock index based on news articles.",
    tools=[predict_index]
)

root_agent = Agent(
    name="news_agent_v1",
    model="gemini-2.0-flash", # Can be a string for Gemini or a LiteLlm object
    description="Analyzes market news to predict stock index trends.",
    instruction="You are a helpful finance assistant. When the user asks for a prediction about a specific index(like DOW or N225), use the 'predict_index_price_agent' tool to provide a prediction.",

    tools=[
        
        AgentTool(google_search_agent, skip_summarization=False),
        AgentTool(predict_agent, skip_summarization=False)
        
    ]
)
# Out:
# Overwriting ./adk_agents/agent1_news_collector/agent.py

# %%
from adk_agents.agent1_news_collector import agent
from adk_agents.agent1_news_collector import tools

importlib.reload(agent)  # Force reload
importlib.reload(tools)  # Force reload

# Example tool usage (optional test)
print(agent.fetch_stock_news_from_google_news("Dow jones"))


print(agent.predict_index("n225","US stock market today: Nasdaq dropped 1.9%, S&P 500 lost 1.1%, Dow slipped 0.8% — What led to Wall Street turning red and why Tesla, Nvidia, Amazon, and Palantir sank"))
# Out:
# ✅ 検索キーワード: 'Dow jones' でGoogle Newsを検索中...
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': 'Is Market Bounce An Opportunity Or Head Fake?', 'source': None, 'date': '2 hours ago', 'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-what-to-do-bulls-fight-back-nvidia/&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQICBAC&usg=AOvVaw1EEizrbe-wnGmp8KoBXa8R', 'summary': 'Dow Jones futures will open Sunday evening, along with S&P 500 futures and Nasdaq futures. The stock market rally suffered sharp losses in the latest week,...'}, 'article_2': {'title': 'Stock Market Today - Wall Street Falls as Nasdaq Drops 3% and Tesla Slides 3.7%', 'source': None, 'date': '7 hours ago', 'url': 'https://www.tradingnews.com/news/stock-market-today-nasdaq-plungs-3-percent-ai-sellfof&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIBhAC&usg=AOvVaw24EVik5hf8SURqKjO806_9', 'summary': 'Trading News Stock Market Today Nasdaq plunges 3% amid AI valuation fears; S&P 500 and Dow slip. Tesla drops 3.7%, Nvidia 9.5%, while gold holds near $4,00.'}, 'article_3': {'title': 'Stock Market Week Ahead: Dow Stocks, Nukes And Maybe A Rebound', 'source': None, 'date': '9 hours ago', 'url': 'https://www.investors.com/research/investing-action-plan/stock-market-week-ahead-dow-stocks-nukes-and-maybe-a-rebound/&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIChAC&usg=AOvVaw3JDKcKxEFmcpZG-NOA2sdw', 'summary': 'The stock market faces a couple of dramas in the coming week: one in Congress, and the other a possible technical rebound.'}, 'article_4': {'title': 'Synaptics (NASDAQ: SYNA) Trends in Dow Jones Industrial Average Technology Stocks', 'source': None, 'date': '9 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/technology/synaptics-nasdaq-syna-trends-in-dow-jones-industrial-average-technology-stocks&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIBRAC&usg=AOvVaw0rq6zrtOR2-Cf35rfUhInW', 'summary': 'Explore Synaptics (NASDAQ: SYNA) operations in semiconductor, AI, and connectivity technologies, reflecting performance in key indices such as Dow Jones...'}, 'article_5': {'title': 'Prospect Capital Corporation Dividend Reflects Stability Amid Dow Jones Industrial Average', 'source': None, 'date': '9 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/financial/prospect-capital-corporation-dividend-reflects-stability-amid-dow-jones-industrial-average&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIARAC&usg=AOvVaw2h4_-pvyq74GlNVV-4ih_3', 'summary': 'Prospect Capital Corporation (NASDAQ: PSEC) maintains its monthly dividend, demonstrating consistent financial management within the Financial Stocks sector...'}, 'article_6': {'title': 'Wix.com Ltd Strengthens Position amid Dow Jones Industrial Average Landscape', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/news/stock-market/wixcom-ltd-strengthens-position-amid-dow-jones-industrial-average-landscape&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIBxAC&usg=AOvVaw0KqJCKNZJIpzuTHzaQj8hK', 'summary': "O'Brien Greene & Co. Inc. has disclosed an acquisition of Wix.com Ltd shares, emphasising the company's presence within technology and digital..."}, 'article_7': {'title': 'Stable Dividend Performers Across the Dow Jones Industrial Average', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/news/market-updates/stable-dividend-performers-across-the-dow-jones-industrial-average&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIAxAC&usg=AOvVaw2_armW_UdwgTFJ0-uDWVVF', 'summary': 'Explore the enduring corporate strength of Johnson & Johnson, Procter & Gamble, and Coca-Cola—key blue-chip dividend entities listed within major US market...'}, 'article_8': {'title': 'Abivax Advances in Biopharma Innovation Amid Dow Jones Industrial Average Trends', 'source': None, 'date': '1 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/healthcare/abivax-advances-in-biopharma-innovation-amid-dow-jones-industrial-average-trends&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQICRAC&usg=AOvVaw2oaMnjdCIeeHx0BFSgFn3-', 'summary': "Expl ...
# {'status': 'OK'}
# ######data {'article_1': {'title': 'Is Market Bounce An Opportunity Or Head Fake?', 'source': None, 'date': '2 hours ago', 'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-what-to-do-bulls-fight-back-nvidia/&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQICBAC&usg=AOvVaw1EEizrbe-wnGmp8KoBXa8R', 'summary': 'Dow Jones futures will open Sunday evening, along with S&P 500 futures and Nasdaq futures. The stock market rally suffered sharp losses in the latest week,...'}, 'article_2': {'title': 'Stock Market Today - Wall Street Falls as Nasdaq Drops 3% and Tesla Slides 3.7%', 'source': None, 'date': '7 hours ago', 'url': 'https://www.tradingnews.com/news/stock-market-today-nasdaq-plungs-3-percent-ai-sellfof&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIBhAC&usg=AOvVaw24EVik5hf8SURqKjO806_9', 'summary': 'Trading News Stock Market Today Nasdaq plunges 3% amid AI valuation fears; S&P 500 and Dow slip. Tesla drops 3.7%, Nvidia 9.5%, while gold holds near $4,00.'}, 'article_3': {'title': 'Stock Market Week Ahead: Dow Stocks, Nukes And Maybe A Rebound', 'source': None, 'date': '9 hours ago', 'url': 'https://www.investors.com/research/investing-action-plan/stock-market-week-ahead-dow-stocks-nukes-and-maybe-a-rebound/&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIChAC&usg=AOvVaw3JDKcKxEFmcpZG-NOA2sdw', 'summary': 'The stock market faces a couple of dramas in the coming week: one in Congress, and the other a possible technical rebound.'}, 'article_4': {'title': 'Synaptics (NASDAQ: SYNA) Trends in Dow Jones Industrial Average Technology Stocks', 'source': None, 'date': '9 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/technology/synaptics-nasdaq-syna-trends-in-dow-jones-industrial-average-technology-stocks&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIBRAC&usg=AOvVaw0rq6zrtOR2-Cf35rfUhInW', 'summary': 'Explore Synaptics (NASDAQ: SYNA) operations in semiconductor, AI, and connectivity technologies, reflecting performance in key indices such as Dow Jones...'}, 'article_5': {'title': 'Prospect Capital Corporation Dividend Reflects Stability Amid Dow Jones Industrial Average', 'source': None, 'date': '9 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/financial/prospect-capital-corporation-dividend-reflects-stability-amid-dow-jones-industrial-average&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIARAC&usg=AOvVaw2h4_-pvyq74GlNVV-4ih_3', 'summary': 'Prospect Capital Corporation (NASDAQ: PSEC) maintains its monthly dividend, demonstrating consistent financial management within the Financial Stocks sector...'}, 'article_6': {'title': 'Wix.com Ltd Strengthens Position amid Dow Jones Industrial Average Landscape', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/news/stock-market/wixcom-ltd-strengthens-position-amid-dow-jones-industrial-average-landscape&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIBxAC&usg=AOvVaw0KqJCKNZJIpzuTHzaQj8hK', 'summary': "O'Brien Greene & Co. Inc. has disclosed an acquisition of Wix.com Ltd shares, emphasising the company's presence within technology and digital..."}, 'article_7': {'title': 'Stable Dividend Performers Across the Dow Jones Industrial Average', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/news/market-updates/stable-dividend-performers-across-the-dow-jones-industrial-average&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQIAxAC&usg=AOvVaw2_armW_UdwgTFJ0-uDWVVF', 'summary': 'Explore the enduring corporate strength of Johnson & Johnson, Procter & Gamble, and Coca-Cola—key blue-chip dividend entities listed within major US market...'}, 'article_8': {'title': 'Abivax Advances in Biopharma Innovation Amid Dow Jones Industrial Average Trends', 'source': None, 'date': '1 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/healthcare/abivax-advances-in-biopharma-innovation-amid-dow-jones-industrial-average-trends&ved=2ahUKEwi6qqKZ6uOQAxXP6RoGHU2TBwEQxfQBegQICRAC&usg=AOvVaw2oaMnjdCIeeHx0BFSgFn3-', 'summary': "Explore Abivax's  ...
# Gemini Clientの初期化しました
# {'prediction_status': 'success', 'target_index': 'n225', 'llm_output': {'predicted_close': 'current index value', 'market_sentiment': 'Bearish', 'analysis_basis': 'US markets, including Nasdaq, S&P 500, and Dow, saw sharp declines amid AI valuation fears and a tech sell-off. Major tech stocks like Nvidia, Tesla, and AMD plunged, indicating widespread bearish sentiment.'}}

# %%
APP_NAME = "stocks_market_app"
USER_ID = "user_1"
SESSION_ID = "session_010"  # Using a fixed ID for simplicity

# %%
session_service = InMemorySessionService()

# Create the specific session where the conversation will happen
session = await session_service.create_session(
    app_name=APP_NAME, user_id=USER_ID, session_id=SESSION_ID
)

# %%
runner = Runner(
    agent=agent.root_agent,  # The agent we want to run
    app_name=APP_NAME,  # Associates runs with our app
    session_service=session_service,  # Uses our session manager
)

# %%
async def call_agent_async(query: str, runner, user_id, session_id):
    """Sends a query to the agent and prints the final response."""
    print(f"\n>>> User Query: {query}")

    content = types.Content(role="user", parts=[types.Part(text=query)])

    final_response_text = "Agent did not produce a final response."  # Default

    # Key Concept: run_async executes the agent logic and yields Events.
    # We iterate through events to find the final answer.
    async for event in runner.run_async(
        user_id=user_id, session_id=session_id, new_message=content
    ):
        # You can uncomment the line below to see *all* events during execution
        # print(f"  [Event] Author: {event.author}, Type: {type(event).__name__}, Final: {event.is_final_response()}, Content: {event.content}")

        # Key Concept: is_final_response() marks the concluding message for the turn.
        if event.is_final_response():
            if event.content and event.content.parts:
                # Assuming text response in the first part
                final_response_text = event.content.parts[0].text
            elif (
                event.actions and event.actions.escalate
            ):  # Handle potential errors/escalations
                final_response_text = f"Agent escalated: {event.error_message or 'No specific message.'}"
            # Add more checks here if needed (e.g., specific error codes)
            break  # Stop processing events once the final response is found

    print(f"<<< Agent Response: {final_response_text}")

# %%
await call_agent_async(
    "search November 7th 2025 news,and then  predict today's DOW Jones-close-price",
    runner=runner,
    user_id=USER_ID,
    session_id=SESSION_ID,
)
# Out:
# >>> User Query: search November 7th 2025 news,and then  predict today's DOW Jones-close-price
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ✅ 検索キーワード: 'November 7th 2025 news' でGoogle Newsを検索中...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': 'OHL Highlights: Brantford Bulldogs @ Oshawa Generals Nov. 7, 2025', 'source': None, 'date': '1 hour ago', 'url': 'https://www.youtube.com/watch%3Fv%3DQUSBBplQkUQ&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIBRAC&usg=AOvVaw37Vz7T_FQQjhsJKnoTRp2V', 'summary': 'Watch OHL Hockey Live on FloHockey: https://flosports.link/4mRdGvc Breaking news, scores, stats & highlights: https://ontariohockeyleague.com Follow the OHL...'}, 'article_2': {'title': 'Supreme Court justice temporarily pauses order requiring Trump administration to fully fund SNAP by end of Friday', 'source': None, 'date': '3 hours ago', 'url': 'https://abcnews.go.com/US/trump-administration-asks-appeals-court-immediately-halt-ruling/story%3Fid%3D127294307&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIBxAC&usg=AOvVaw1c3n5wUwLfzWU0O0WlENr4', 'summary': "A Supreme Court justice has temporarily paused a lower court's ruling requiring the Trump administration to fully fund the SNAP program by the end of the..."}, 'article_3': {'title': 'More than 1,000 flights canceled today largely due to cuts tied to shutdown as travelers face delays', 'source': None, 'date': '3 hours ago', 'url': 'https://www.cbsnews.com/live-updates/canceled-flights-government-shutdown-airlines-scramble/&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIChAC&usg=AOvVaw3E7NMt4hPDK0eS9HvhmjJ_', 'summary': 'The FAA ordered airlines to cut thousands of flights ahead of this weekend as the agency deals with air traffic controller shortages during the government...'}, 'article_4': {'title': "Man dies after slipping and falling off edge of the Grand Canyon: Sheriff's office", 'source': None, 'date': '4 hours ago', 'url': 'https://abcnews.go.com/US/man-dies-after-slipping-falling-off-edge-grand/story%3Fid%3D127319053&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIAhAC&usg=AOvVaw0mZXD8bczgPdT-0KIa6FtW', 'summary': "The incident occurred at Guano Point on the canyon's west rim, according to the Mohave County Sheriff's Office."}, 'article_5': {'title': 'The Take @ 2: November 7th, 2025', 'source': None, 'date': '5 hours ago', 'url': 'https://www.yahoo.com/news/videos/2-november-7th-2025-200508123.html&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIAxAC&usg=AOvVaw2xqTBRAZlxB1glKBWnByZ4', 'summary': 'The Take @ 2 - a first-of-its-kind show where the viewers drive the conversation. Share yours at 202-895-3200.'}, 'article_6': {'title': 'Sask. woman face charges after alleged triple homicide | CTV News Saskatoon: Friday, Nov. 7, 2025', 'source': None, 'date': '7 hours ago', 'url': 'https://www.youtube.com/watch%3Fv%3D1yEeKDe2Y1g&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIBhAC&usg=AOvVaw0fj5cPzaseaV_IPe0Pk38v', 'summary': 'Sask. woman face charges after alleged triple homicide | CTV News Saskatoon: Friday, Nov. 7, 2025. 1.6K views · 6 hours ago #ctvnews #ctvnationalnews #...'}, 'article_7': {'title': 'Weekend flight delays, cancellations, climb in Southern California, as government shutdown drags on', 'source': None, 'date': '8 hours ago', 'url': 'https://www.dailynews.com/2025/11/08/weekend-flight-delays-cancellations-climb-in-southern-california-as-government-shutdown-drags-on/&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQICRAC&usg=AOvVaw12L3JXxxfcofyk2dNyXtxN', 'summary': 'LOS ANGELES — Traveler discomfort is expected to continue Saturday, Nov. 8, as flight delays and cancellations imposed by the U.S. Department of...'}, 'article_8': {'title': 'Nightline Full Broadcast — Friday, November 7, 2025', 'source': None, 'date': '9 hours ago', 'url': 'https://www.youtube.com/watch%3Fv%3DbAiw6_VFfgM&ved=2ahUKEwiBs5mm6uOQAxXf4ckDHcy_HosQxfQBegQIBBAC&usg=AOvVaw3Py7Pca8R-TxuqHgc1r9Un', 'summary': "00:00 Intro 01:29 Uproar over comments made by a Miss Universe organization leader to a contestant 09:12 'Dance Moms' star Nia Sioux tells all in memoir..."}, 'article_9': {'title': 'KREM 2 News at 10 Headlines, November 7, 2025', 'source': None, 'date': '9 hours ago', 'url': 'https://www.youtube ...
# <<< Agent Response: I am sorry, I cannot provide you with news articles dated November 7th 2025, as I can only access recent news. What is the query you want me to use to predict the DOW Jones closing price?

# %%
# !adk web adk_agents

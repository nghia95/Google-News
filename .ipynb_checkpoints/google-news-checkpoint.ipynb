# %%
import asyncio
import importlib
import os
import warnings

from google.adk.agents import Agent
#from google.adk.models.lite_llm import LiteLlm  # For multi-model support
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools.tool_context import ToolContext
from google.genai import types  # For creating message Content/Parts
from IPython.display import HTML, Markdown, display

# Ignore all warnings
warnings.filterwarnings("ignore")

import logging

logging.basicConfig(level=logging.ERROR)

# Set `PATH` to include the directory containing ADK command
# PATH = %env PATH
# %env PATH=/home/jupyter/.local/bin:{PATH}

# %%
LOCATION = "us-central1"
os.environ["GOOGLE_CLOUD_LOCATION"] = LOCATION
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "TRUE"  # Use Vertex AI API
os.environ["GOOGLE_CLOUD_PROJECT"] = "nghiale-demo"  # Use Vertex AI API

# %%
# %%bash
# # -p オプションを付けて adk_agents/ ディレクトリを作成します。
# # -p は、ディレクトリが既に存在してもエラーを出さず、親ディレクトリも同時に作成します。
# mkdir -p adk_agents

# %%
# %%bash
# echo > adk_agents/.env "GOOGLE_CLOUD_LOCATION=$GOOGLE_CLOUD_LOCATION
# GOOGLE_CLOUD_PROJECT=$GOOGLE_CLOUD_PROJECT
#
# GOOGLE_GENAI_USE_VERTEXAI=$GOOGLE_GENAI_USE_VERTEXAI
# "

# %%
MODEL = "gemini-2.0-flash"

# %%
# %%bash
# # 必要なディレクトリ構造をすべて作成します。
# # -p オプションは、パスの中間にあるディレクトリもすべて作成し、
# # すでに存在してもエラーを出さないため安全です。
# mkdir -p ./adk_agents/agent1_news_collector

# %%
# %%writefile ./adk_agents/agent1_news_collector/tools.py

import pandas as pd
from GoogleNews import GoogleNews # GoogleNewsなどの必要なライブラリもインポート
import json
from google import genai
from google.genai.errors import APIError

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)


def fetch_stock_news_from_google_news(query:str):
    """Retrieves recent news articles related to a specific financial or market query from Google News.

    Args:
        query (str): The keyword or phrase for the search (e.g., "Toyota stock forecast", "Nikkei 225 news").
        
    Returns:
        dict: A Data dictionary containing the collected news data (e.g., Title, Summary, Source, URL).
    """
    print(f"✅ 検索キーワード: '{query}' でGoogle Newsを検索中...")

    # GoogleNewsオブジェクトを初期化
    googlenews = GoogleNews(lang='en', region='US') # 日本語、日本リージョンで設定
    # googlenews = GoogleNews(lang='ja', region='ja') # 日本語、日本リージョンで設定
    # 検索クエリを設定し、指定ページ数まで結果を取得
    googlenews.search(query)
    
    # 結果を取得
    results = googlenews.results()
    
    news_data = {} # 辞書型として初期化
    article_index = 1 # 記事のキーとして使用するカウンター

    for item in results:
        # 必要な情報を抽出し、一時的なディクショナリ（記事データ）を作成
        article_dict = {
            'title': item.get('title'),
            'source': item.get('publisher'),
            'date': item.get('date'),
            'url': item.get('link'),
            'summary': item.get('desc')
        }
    
        # 💡 修正点: .append() の代わりに、連番をキーとしてディクショナリに保存
        news_data[f'article_{article_index}'] = article_dict
        
        # 次のキーのためにカウンターを増やす
        article_index += 1
    
    if not news_data:
        print("❌ 該当するニュース記事が見つかりませんでした。")
        return {
            "status": "failed",
            "count": 0,
            "message": "No news articles found for the query.",
            "articles": []
        }

    print(f"✅ 合計 {len(news_data)} 件の記事が見つかりました。")

    # ファイルに書き込む
    with open("./data.json", 'w', encoding='utf-8') as f:
        # indent=4 で整形して書き込むと、ファイルが読みやすくなります
        json.dump(news_data, f)

    return {"status": "OK"}


def predict_index(target_index: str) -> dict:
    """The minimum function required to analyze news articles and have Gemini generate a prediction and its rationale."""
    # ----------------------------------------------------
    # 💡 注意: clientは通常モジュールレベルで一度だけ初期化します
    # ファイルを読み込む
    with open("./data.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    try:
        client = genai.Client()
        print("Gemini Clientの初期化しました")
    except Exception as e:
        # 環境変数または認証情報に問題がある可能性があります
        print(f"Gemini Clientの初期化に失敗しました: {e}")
        client = None
    # ----------------------------------------------------
    # 1. 最小限の初期チェック
    if client is None:
        return {"status": "error", "message": "Client not initialized."}

    # if not query:
    #     return {"status": "data_insufficient", "message": "No news data provided."}

    
    # 3. 最小限のプロンプトと必須JSON形式
    prompt = f"""
    Based *only* on the provided news articles in the {data}, analyze the sentiment and predict the closing direction for the **{target_index}** index. 
    Output the result strictly in the required JSON format.

    Required JSON Format:
    {{
      "predicted_close": <float or current index value>,
      "market_sentiment": "<Bullish|Bearish|Neutral>",
      "analysis_basis": "<Concise summary of the market drivers, max 50 words>"
    }}
    """
    
    # 4. API呼び出しと最小限のエラー処理
    try:
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=prompt,
            config={"response_mime_type": "application/json"}
        )
        
        # JSON応答をパース
        llm_analysis = json.loads(response.text)
        
        # 💡 デバッグ用: 応答が成功した場合、Geminiの解析結果をそのまま返して構造を確認
        return {
            "prediction_status": "success",
            "target_index": target_index,
            "llm_output": llm_analysis # 解析結果全体を返して確認
        }

    except Exception as e:
        # ネットワーク、認証、JSONパースなど、全てのエラーをキャッチ
        return {
            "prediction_status": "runtime_error",
            "message": f"An unexpected error occurred during API call or JSON parsing: {type(e).__name__}: {str(e)}",
            "error_type": type(e).__name__
        }
# Out:
# Overwriting ./adk_agents/agent1_news_collector/tools.py

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
# %%writefile ./adk_agents/agent1_news_collector/agent.py
from google.adk.agents import Agent
from google.adk.tools import AgentTool

from .tools import fetch_stock_news_from_google_news, predict_index

google_search_agent = Agent(
    name="google_search_agent",
    model="gemini-2.0-flash",
    instruction="Retrieves recent news articles from Google News.",
    tools=[fetch_stock_news_from_google_news]
)

predict_agent = Agent(
    name="predict_index_price_agent",
    model="gemini-2.0-flash",
    instruction="Predict the closing price of a stock index based on news articles.",
    tools=[predict_index]
)

root_agent = Agent(
    name="news_agent_v1",
    model="gemini-2.0-flash", # Can be a string for Gemini or a LiteLlm object
    description="Analyzes market news to predict stock index trends.",
    instruction="You are a helpful finance assistant. When the user asks for a prediction about a specific index(like DOW or N225), you will provide a prediction about the close price of that index using the following step:   1. Use the 'google_search_agent' tool to find the latest news about that index and output it to the data.json file2. Use the 'predict_agent' tool to provide the prediction of the closed price of the index, pass the name of the index to the 'target_index' parameter 3. Output the prediction in natural language",
    tools=[
        
        AgentTool(google_search_agent, skip_summarization=False),
        AgentTool(predict_agent, skip_summarization=False)
        
    ]
)
# Out:
# Overwriting ./adk_agents/agent1_news_collector/agent.py

# %%
from adk_agents.agent1_news_collector import agent
from adk_agents.agent1_news_collector import tools

importlib.reload(agent)  # Force reload
importlib.reload(tools)  # Force reload

# Example tool usage (optional test)
print(agent.fetch_stock_news_from_google_news("Dow jones"))


print(agent.predict_index("n225"))
# Out:
# ✅ 検索キーワード: 'Dow jones' でGoogle Newsを検索中...
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': 'Is Market Bounce An Opportunity Or Head Fake?', 'source': None, 'date': '3 hours ago', 'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-what-to-do-bulls-fight-back-nvidia/&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQICRAC&usg=AOvVaw1r8KFQvJQCzGyEHmjppWqE', 'summary': 'Dow Jones futures will open Sunday evening, along with S&P 500 futures and Nasdaq futures. The stock market rally suffered sharp losses in the latest week,...'}, 'article_2': {'title': 'Stock Market Today - Wall Street Falls as Nasdaq Drops 3% and Tesla Slides 3.7%', 'source': None, 'date': '8 hours ago', 'url': 'https://www.tradingnews.com/news/stock-market-today-nasdaq-plungs-3-percent-ai-sellfof&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQICBAC&usg=AOvVaw1cjz-2o8845lZ7vbA4qfvf', 'summary': 'Trading News Stock Market Today Nasdaq plunges 3% amid AI valuation fears; S&P 500 and Dow slip. Tesla drops 3.7%, Nvidia 9.5%, while gold holds near $4,00.'}, 'article_3': {'title': 'Stock Market Week Ahead: Dow Stocks, Nukes And Maybe A Rebound', 'source': None, 'date': '0 hours ago', 'url': 'https://www.investors.com/research/investing-action-plan/stock-market-week-ahead-dow-stocks-nukes-and-maybe-a-rebound/&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIChAC&usg=AOvVaw3Y0HLtIuiYfqQei6xuqxrx', 'summary': 'The stock market faces a couple of dramas in the coming week: one in Congress, and the other a possible technical rebound.'}, 'article_4': {'title': 'Synaptics (NASDAQ: SYNA) Trends in Dow Jones Industrial Average Technology Stocks', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/technology/synaptics-nasdaq-syna-trends-in-dow-jones-industrial-average-technology-stocks&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIBBAC&usg=AOvVaw0f8H-LeMLEbyHmo_AGMpXh', 'summary': 'Explore Synaptics (NASDAQ: SYNA) operations in semiconductor, AI, and connectivity technologies, reflecting performance in key indices such as Dow Jones...'}, 'article_5': {'title': 'Prospect Capital Corporation Dividend Reflects Stability Amid Dow Jones Industrial Average', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/financial/prospect-capital-corporation-dividend-reflects-stability-amid-dow-jones-industrial-average&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIAxAC&usg=AOvVaw12bGaQm9Gz6x3ji_in1iEf', 'summary': 'Prospect Capital Corporation (NASDAQ: PSEC) maintains its monthly dividend, demonstrating consistent financial management within the Financial Stocks sector...'}, 'article_6': {'title': 'Wix.com Ltd Strengthens Position amid Dow Jones Industrial Average Landscape', 'source': None, 'date': '1 hours ago', 'url': 'https://kalkinemedia.com/us/news/stock-market/wixcom-ltd-strengthens-position-amid-dow-jones-industrial-average-landscape&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIAhAC&usg=AOvVaw1bEUOQRO5Kkh7LEH26nTST', 'summary': "O'Brien Greene & Co. Inc. has disclosed an acquisition of Wix.com Ltd shares, emphasising the company's presence within technology and digital..."}, 'article_7': {'title': 'Exclusive | Nancy Pelosi made $130M in stock profits during Congress career — a return of 16,930%', 'source': None, 'date': '1 hours ago', 'url': 'https://nypost.com/2025/11/08/us-news/nancy-pelosi-made-130-million-in-stock-profits-in-her-37-years-in-congress-a-profit-of-16930/&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIBxAC&usg=AOvVaw3cAjW7pzw1P9LlWJLmqG13', 'summary': 'Before taking Congressional office in 1988, the then-47-year-old freshman and her hubby, venture capitalist Paul Pelosi, reported between $610000 and...'}, 'article_8': {'title': 'Stable Dividend Performers Across the Dow Jones Industrial Average', 'source': None, 'date': '1 hours ago', 'url': 'https://kalkinemedia.com/us/news/market-updates/stable-dividend-performers-across-the-dow-jones-industrial-average&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIBRAC&usg=AOvVaw0raE4HdYuiv_W2R1qVQoz6',  ...
# {'status': 'OK'}
# ######data {'article_1': {'title': 'Is Market Bounce An Opportunity Or Head Fake?', 'source': None, 'date': '3 hours ago', 'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-what-to-do-bulls-fight-back-nvidia/&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQICRAC&usg=AOvVaw1r8KFQvJQCzGyEHmjppWqE', 'summary': 'Dow Jones futures will open Sunday evening, along with S&P 500 futures and Nasdaq futures. The stock market rally suffered sharp losses in the latest week,...'}, 'article_2': {'title': 'Stock Market Today - Wall Street Falls as Nasdaq Drops 3% and Tesla Slides 3.7%', 'source': None, 'date': '8 hours ago', 'url': 'https://www.tradingnews.com/news/stock-market-today-nasdaq-plungs-3-percent-ai-sellfof&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQICBAC&usg=AOvVaw1cjz-2o8845lZ7vbA4qfvf', 'summary': 'Trading News Stock Market Today Nasdaq plunges 3% amid AI valuation fears; S&P 500 and Dow slip. Tesla drops 3.7%, Nvidia 9.5%, while gold holds near $4,00.'}, 'article_3': {'title': 'Stock Market Week Ahead: Dow Stocks, Nukes And Maybe A Rebound', 'source': None, 'date': '0 hours ago', 'url': 'https://www.investors.com/research/investing-action-plan/stock-market-week-ahead-dow-stocks-nukes-and-maybe-a-rebound/&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIChAC&usg=AOvVaw3Y0HLtIuiYfqQei6xuqxrx', 'summary': 'The stock market faces a couple of dramas in the coming week: one in Congress, and the other a possible technical rebound.'}, 'article_4': {'title': 'Synaptics (NASDAQ: SYNA) Trends in Dow Jones Industrial Average Technology Stocks', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/technology/synaptics-nasdaq-syna-trends-in-dow-jones-industrial-average-technology-stocks&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIBBAC&usg=AOvVaw0f8H-LeMLEbyHmo_AGMpXh', 'summary': 'Explore Synaptics (NASDAQ: SYNA) operations in semiconductor, AI, and connectivity technologies, reflecting performance in key indices such as Dow Jones...'}, 'article_5': {'title': 'Prospect Capital Corporation Dividend Reflects Stability Amid Dow Jones Industrial Average', 'source': None, 'date': '0 hours ago', 'url': 'https://kalkinemedia.com/us/stocks/financial/prospect-capital-corporation-dividend-reflects-stability-amid-dow-jones-industrial-average&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIAxAC&usg=AOvVaw12bGaQm9Gz6x3ji_in1iEf', 'summary': 'Prospect Capital Corporation (NASDAQ: PSEC) maintains its monthly dividend, demonstrating consistent financial management within the Financial Stocks sector...'}, 'article_6': {'title': 'Wix.com Ltd Strengthens Position amid Dow Jones Industrial Average Landscape', 'source': None, 'date': '1 hours ago', 'url': 'https://kalkinemedia.com/us/news/stock-market/wixcom-ltd-strengthens-position-amid-dow-jones-industrial-average-landscape&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIAhAC&usg=AOvVaw1bEUOQRO5Kkh7LEH26nTST', 'summary': "O'Brien Greene & Co. Inc. has disclosed an acquisition of Wix.com Ltd shares, emphasising the company's presence within technology and digital..."}, 'article_7': {'title': 'Exclusive | Nancy Pelosi made $130M in stock profits during Congress career — a return of 16,930%', 'source': None, 'date': '1 hours ago', 'url': 'https://nypost.com/2025/11/08/us-news/nancy-pelosi-made-130-million-in-stock-profits-in-her-37-years-in-congress-a-profit-of-16930/&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIBxAC&usg=AOvVaw3cAjW7pzw1P9LlWJLmqG13', 'summary': 'Before taking Congressional office in 1988, the then-47-year-old freshman and her hubby, venture capitalist Paul Pelosi, reported between $610000 and...'}, 'article_8': {'title': 'Stable Dividend Performers Across the Dow Jones Industrial Average', 'source': None, 'date': '1 hours ago', 'url': 'https://kalkinemedia.com/us/news/market-updates/stable-dividend-performers-across-the-dow-jones-industrial-average&ved=2ahUKEwit4Jvj9eOQAxV_GtAFHRu5F5UQxfQBegQIBRAC&usg=AOvVaw0raE4HdYuiv_W2R1qVQoz6', 'summary': 'E ...
# Gemini Clientの初期化しました
# {'prediction_status': 'success', 'target_index': 'n225', 'llm_output': {'predicted_close': None, 'market_sentiment': 'Neutral', 'analysis_basis': 'Provided articles focus solely on US market downturns (Dow, S&P 500, Nasdaq) due to tech sell-offs and AI fears, offering no information to predict N225 trends.'}}

# %%
APP_NAME = "stocks_market_app"
USER_ID = "user_1"
SESSION_ID = "session_010"  # Using a fixed ID for simplicity

# %%
session_service = InMemorySessionService()

# Create the specific session where the conversation will happen
session = await session_service.create_session(
    app_name=APP_NAME, user_id=USER_ID, session_id=SESSION_ID
)

# %%
runner = Runner(
    agent=agent.root_agent,  # The agent we want to run
    app_name=APP_NAME,  # Associates runs with our app
    session_service=session_service,  # Uses our session manager
)

# %%
async def call_agent_async(query: str, runner, user_id, session_id):
    """Sends a query to the agent and prints the final response."""
    print(f"\n>>> User Query: {query}")

    content = types.Content(role="user", parts=[types.Part(text=query)])

    final_response_text = "Agent did not produce a final response."  # Default

    # Key Concept: run_async executes the agent logic and yields Events.
    # We iterate through events to find the final answer.
    async for event in runner.run_async(
        user_id=user_id, session_id=session_id, new_message=content
    ):
        # You can uncomment the line below to see *all* events during execution
        # print(f"  [Event] Author: {event.author}, Type: {type(event).__name__}, Final: {event.is_final_response()}, Content: {event.content}")

        # Key Concept: is_final_response() marks the concluding message for the turn.
        if event.is_final_response():
            if event.content and event.content.parts:
                # Assuming text response in the first part
                final_response_text = event.content.parts[0].text
            elif (
                event.actions and event.actions.escalate
            ):  # Handle potential errors/escalations
                final_response_text = f"Agent escalated: {event.error_message or 'No specific message.'}"
            # Add more checks here if needed (e.g., specific error codes)
            break  # Stop processing events once the final response is found

    print(f"<<< Agent Response: {final_response_text}")

# %%
await call_agent_async(
    "Search the news and predict today's Nasdaq close-price",
    runner=runner,
    user_id=USER_ID,
    session_id=SESSION_ID,
)
# Out:
# >>> User Query: Search the news and predict today's Nasdaq close-price
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call', 'function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ✅ 検索キーワード: 'Nasdaq news' でGoogle Newsを検索中...
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ✅ 合計 10 件の記事が見つかりました。
# ####################### {'article_1': {'title': 'Nasdaq (NDAQ): How the LSEG Data Partnership Shapes a Fresh Look at Valuation', 'source': None, 'date': '2 hours ago', 'url': 'https://simplywall.st/stocks/us/diversified-financials/nasdaq-ndaq/nasdaq/news/nasdaq-ndaq-how-the-lseg-data-partnership-shapes-a-fresh-loo&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIBxAC&usg=AOvVaw1CWS6a1uiXITpbDRFe3vOl', 'summary': "Nasdaq (NDAQ) has announced a new partnership with LSEG. Its private markets datasets will be licensed and distributed through LSEG's platforms."}, 'article_2': {'title': 'Stock Market News Today', 'source': None, 'date': '2 hours ago', 'url': 'https://www.stocktitan.net/news/2025-11-08/&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQICBAC&usg=AOvVaw2oNDsE_-6lJHZI96k9oMBt', 'summary': 'A leading AI‑powered platform for real‑time stock market news, press releases, SEC filings, earnings, and tools for trading and investing. ©...'}, 'article_3': {'title': 'Nasdaq Hits Worst Week Since April Amid AI Rally Concerns', 'source': None, 'date': '4 hours ago', 'url': 'https://www.rswebsols.com/news/nasdaq-experiences-its-worst-week-since-april-amid-ai-rally-concerns-and-declining-us-yields/&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIChAC&usg=AOvVaw2i5Ttc_G8W4GVTkHR0hagd', 'summary': 'Nasdaq suffers its worst week since April as AI rally fears and falling US yields shake investor confidence. Discover what this means for the market now.'}, 'article_4': {'title': 'QQQM ETF Climbs on $5T Nvidia Surge and $4T Microsoft, Apple Milestones as AI Momentum Lifts Nasdaq', 'source': None, 'date': '4 hours ago', 'url': 'https://www.tradingnews.com/news/qqqm-etf-climbs-on-5y-usd-nvidia-surge-and-4t-usd-msft-apple-milestone&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIAxAC&usg=AOvVaw2MzXzlcaWcYRtVKFK6wQjW', 'summary': 'Trading News Invesco NASDAQ 100 ETF (QQQM) trades near $251.06 as Nvidia hits $5T and Microsoft, Apple exceed $4T. Strong AI momentum, low 0.15% fee, Buy r.'}, 'article_5': {'title': 'CRMT Investor News: If You Have Suffered Losses in', 'source': None, 'date': '4 hours ago', 'url': 'https://www.globenewswire.com/news-release/2025/11/08/3184091/673/en/CRMT-Investor-News-If-You-Have-Suffered-Losses-in-America-s-Car-Mart-Inc-NASDAQ-CRMT-You-Are-Encouraged-to-Contact-The-Rosen-Law-Firm-About-Your-Rights.html&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQICRAC&usg=AOvVaw0wNOwKEv_9Z8BT6xhpBq-W', 'summary': 'NEW YORK, Nov. 08, 2025 (GLOBE NEWSWIRE) -- WHY: Rosen Law Firm, a global investor rights law firm, continues to investigate potential securities...'}, 'article_6': {'title': "Starbucks' Bearista Cup Resale Market Explodes, Labubu-Level Frenzy Ensues", 'source': None, 'date': '6 hours ago', 'url': 'https://www.benzinga.com/news/entertainment/25/11/48739836/starbucks-bearista-cup-resale-market-explodes-labubu-level-frenzy-ensues&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIAhAC&usg=AOvVaw2zbTUQwucKRMx_6lyQBTP1', 'summary': 'Starbucks Corp (NASDAQ:SBUX) has seen a surge in demand for its collectible holiday merchandise, with the Glass Bearista Cold Cup becoming the latest...'}, 'article_7': {'title': 'Nvidia CEO wants TSMC to boost chip supplies amid strong AI demand', 'source': None, 'date': '7 hours ago', 'url': 'https://seekingalpha.com/news/4519048-nvidia-ceo-wants-tsmc-boost-chip-supplies&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIBhAC&usg=AOvVaw1ADYYLg0DhCqyFjrUcxWW3', 'summary': 'Nvidia (NVDA) CEO Jensen Huang seeks additional chip supplies from Taiwan Semiconductor Manufacturing Company (TSM) as AI demand remains strong.'}, 'article_8': {'title': 'Stock Market Today - Wall Street Falls as Nasdaq Drops 3% and Tesla Slides 3.7%', 'source': None, 'date': '8 hours ago', 'url': 'https://www.tradingnews.com/news/stock-market-today-nasdaq-plungs-3-percent-ai-sellfof&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIBBAC&usg=AOvVaw0eTXVrDgxFRr92-NODzSYk', 'summary': 'Trading News Stock Market Today Nasdaq plunges 3% amid AI valuation fears; S ...
# ######data {'article_1': {'title': 'Nasdaq (NDAQ): How the LSEG Data Partnership Shapes a Fresh Look at Valuation', 'source': None, 'date': '2 hours ago', 'url': 'https://simplywall.st/stocks/us/diversified-financials/nasdaq-ndaq/nasdaq/news/nasdaq-ndaq-how-the-lseg-data-partnership-shapes-a-fresh-loo&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIBxAC&usg=AOvVaw1CWS6a1uiXITpbDRFe3vOl', 'summary': "Nasdaq (NDAQ) has announced a new partnership with LSEG. Its private markets datasets will be licensed and distributed through LSEG's platforms."}, 'article_2': {'title': 'Stock Market News Today', 'source': None, 'date': '2 hours ago', 'url': 'https://www.stocktitan.net/news/2025-11-08/&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQICBAC&usg=AOvVaw2oNDsE_-6lJHZI96k9oMBt', 'summary': 'A leading AI‑powered platform for real‑time stock market news, press releases, SEC filings, earnings, and tools for trading and investing. ©...'}, 'article_3': {'title': 'Nasdaq Hits Worst Week Since April Amid AI Rally Concerns', 'source': None, 'date': '4 hours ago', 'url': 'https://www.rswebsols.com/news/nasdaq-experiences-its-worst-week-since-april-amid-ai-rally-concerns-and-declining-us-yields/&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIChAC&usg=AOvVaw2i5Ttc_G8W4GVTkHR0hagd', 'summary': 'Nasdaq suffers its worst week since April as AI rally fears and falling US yields shake investor confidence. Discover what this means for the market now.'}, 'article_4': {'title': 'QQQM ETF Climbs on $5T Nvidia Surge and $4T Microsoft, Apple Milestones as AI Momentum Lifts Nasdaq', 'source': None, 'date': '4 hours ago', 'url': 'https://www.tradingnews.com/news/qqqm-etf-climbs-on-5y-usd-nvidia-surge-and-4t-usd-msft-apple-milestone&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIAxAC&usg=AOvVaw2MzXzlcaWcYRtVKFK6wQjW', 'summary': 'Trading News Invesco NASDAQ 100 ETF (QQQM) trades near $251.06 as Nvidia hits $5T and Microsoft, Apple exceed $4T. Strong AI momentum, low 0.15% fee, Buy r.'}, 'article_5': {'title': 'CRMT Investor News: If You Have Suffered Losses in', 'source': None, 'date': '4 hours ago', 'url': 'https://www.globenewswire.com/news-release/2025/11/08/3184091/673/en/CRMT-Investor-News-If-You-Have-Suffered-Losses-in-America-s-Car-Mart-Inc-NASDAQ-CRMT-You-Are-Encouraged-to-Contact-The-Rosen-Law-Firm-About-Your-Rights.html&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQICRAC&usg=AOvVaw0wNOwKEv_9Z8BT6xhpBq-W', 'summary': 'NEW YORK, Nov. 08, 2025 (GLOBE NEWSWIRE) -- WHY: Rosen Law Firm, a global investor rights law firm, continues to investigate potential securities...'}, 'article_6': {'title': "Starbucks' Bearista Cup Resale Market Explodes, Labubu-Level Frenzy Ensues", 'source': None, 'date': '6 hours ago', 'url': 'https://www.benzinga.com/news/entertainment/25/11/48739836/starbucks-bearista-cup-resale-market-explodes-labubu-level-frenzy-ensues&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIAhAC&usg=AOvVaw2zbTUQwucKRMx_6lyQBTP1', 'summary': 'Starbucks Corp (NASDAQ:SBUX) has seen a surge in demand for its collectible holiday merchandise, with the Glass Bearista Cold Cup becoming the latest...'}, 'article_7': {'title': 'Nvidia CEO wants TSMC to boost chip supplies amid strong AI demand', 'source': None, 'date': '7 hours ago', 'url': 'https://seekingalpha.com/news/4519048-nvidia-ceo-wants-tsmc-boost-chip-supplies&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIBhAC&usg=AOvVaw1ADYYLg0DhCqyFjrUcxWW3', 'summary': 'Nvidia (NVDA) CEO Jensen Huang seeks additional chip supplies from Taiwan Semiconductor Manufacturing Company (TSM) as AI demand remains strong.'}, 'article_8': {'title': 'Stock Market Today - Wall Street Falls as Nasdaq Drops 3% and Tesla Slides 3.7%', 'source': None, 'date': '8 hours ago', 'url': 'https://www.tradingnews.com/news/stock-market-today-nasdaq-plungs-3-percent-ai-sellfof&ved=2ahUKEwiItp7I9uOQAxUk6ckDHbzqJYsQxfQBegQIBBAC&usg=AOvVaw0eTXVrDgxFRr92-NODzSYk', 'summary': 'Trading News Stock Market Today Nasdaq plunges 3% amid AI valuation fears; S&P 500 and Do ...
# Gemini Clientの初期化しました
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# <<< Agent Response: Based on news analysis, the predicted closing price for Nasdaq is the current index value. The rationale is that Nasdaq plunged 3% and had its worst week since April due to AI valuation fears and declining yields, despite some AI-driven ETF gains, leading to a bearish market sentiment.

# %%
# !adk web adk_agents
